# %% [markdown]
# # Funciones de distribucion de probabilidad
#
# ## Distribucion Uniforme

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
coursePath='C:/Users/jcres/Anaconda Projects/Course/python-ml-course-master/'
datasetsPath=coursePath+'datasets/'
workingPath='C:/Users/jcres/Anaconda Projects/Course/1 Data Cleaning/Files/'

# %%
titanicFilename='titanic/titanic3.csv'
customerChurnModelFilename='customer-churn-model/Customer Churn Model.txt'
titanicDataSet=os.path.join(datasetsPath,titanicFilename)
customerChurnModelDataSet=os.path.join(datasetsPath,customerChurnModelFilename)

# %%
a=1
b=100
n=1000000
data=np.random.uniform(a,b,n)

# %%
# %matplotlib inline
plot=plt.hist(data)

# %% [markdown]
# ## Distribucion normal

# %%
data= np.random.randn(10000000)

# %%
x=range(1,10000001)

plt.plot(x,data)

# %%
plt.hist(data)
# Out:
# (array([4.400000e+01, 4.007000e+03, 1.147270e+05, 1.085099e+06,
#         3.449011e+06, 3.758252e+06, 1.403705e+06, 1.774570e+05,
#         7.573000e+03, 1.250000e+02]),
#  array([-5.51776117, -4.43165241, -3.34554365, -2.25943489, -1.17332613,
#         -0.08721737,  0.99889139,  2.08500015,  3.17110891,  4.25721767,
#          5.34332643]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(x,sorted(data))

# %%
mu= 5.5
sd = 2.5
data = mu + sd*np.random.randn(10000)
plt.hist(data)
# Out:
# (array([  25.,  144.,  631., 1716., 2714., 2651., 1475.,  521.,  111.,
#           12.]),
#  array([-3.43692335, -1.60646507,  0.22399321,  2.05445149,  3.88490977,
#          5.71536805,  7.54582633,  9.37628461, 11.20674289, 13.03720117,
#         14.86765945]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## La simulacion de Monter Carlo

# %% [markdown]
# ## Dummy Data Sets

# %%
n=1000000
data = pd.DataFrame(
    {
        'A' : np.random.randn(n),
        'B' : 1.5 + 2.5* np.random.randn(n),
        'C' : np.random.uniform(5,32,n)
    }
    
)

# %%
data.describe()
# Out:
#                     A               B               C
# count  1000000.000000  1000000.000000  1000000.000000
# mean        -0.001756        1.495955       18.504148
# std          1.000002        2.500065        7.793490
# min         -4.883069      -10.998642        5.000007
# 25%         -0.676988       -0.190902       11.747664
# 50%         -0.002558        1.494658       18.507723
# 75%          0.672887        3.182239       25.252258
# max          4.624309       13.378144       31.999965

# %%
plt.hist(data['A'])
# Out:
# (array([5.10000e+01, 1.38800e+03, 1.98760e+04, 1.18920e+05, 3.08978e+05,
#         3.45385e+05, 1.67538e+05, 3.47070e+04, 3.04500e+03, 1.12000e+02]),
#  array([-4.88306879, -3.93233106, -2.98159332, -2.03085559, -1.08011786,
#         -0.12938012,  0.82135761,  1.77209535,  2.72283308,  3.67357081,
#          4.62430855]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['B'])
# Out:
# (array([3.10000e+01, 1.13900e+03, 1.78500e+04, 1.17403e+05, 3.14980e+05,
#         3.51487e+05, 1.63339e+05, 3.11860e+04, 2.51500e+03, 7.00000e+01]),
#  array([-10.99864172,  -8.56096316,  -6.12328459,  -3.68560602,
#          -1.24792745,   1.18975111,   3.62742968,   6.06510825,
#           8.50278681,  10.94046538,  13.37814395]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['C'])
# Out:
# (array([ 99809., 100096., 100086.,  99742., 100003., 100534.,  99533.,
#         100066., 100121., 100010.]),
#  array([ 5.00000663,  7.70000245, 10.39999826, 13.09999407, 15.79998988,
#         18.49998569, 21.1999815 , 23.89997731, 26.59997312, 29.29996893,
#         31.99996474]),
#  <a list of 10 Patch objects>)

# %%
dataC = pd.read_csv(customerChurnModelDataSet)

# %%
dataC.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
column_names=dataC.columns.values.tolist()
a=len(column_names)
a
# Out:
# 21

# %%
new_data = pd.DataFrame(
    {
    'Column Name' : column_names,
    'A' : np.random.randn(a),
    'B' : np.random.uniform(2,12,a)
}
    )

# %%
new_data
# Out:
#        Column Name         A          B
# 0            State  0.043299  10.714535
# 1   Account Length  0.947461   5.607897
# 2        Area Code  0.564564   4.720884
# 3            Phone -2.427502   3.557495
# 4       Int'l Plan  1.427372   6.986236
# 5       VMail Plan -2.404263   7.981216
# 6    VMail Message -1.238885   9.806388
# 7         Day Mins  2.135236   5.527211
# 8        Day Calls  0.802867   7.221295
# 9       Day Charge  1.025181  10.935661
# 10        Eve Mins  0.181320   8.016777
# 11       Eve Calls -0.794876  11.516676
# 12      Eve Charge  0.535404   4.657973
# 13      Night Mins  0.823819   5.235021
# 14     Night Calls  0.935715  10.184529
# 15    Night Charge -0.102242   6.460591
# 16       Intl Mins -0.031512   5.224810
# 17      Intl Calls -0.643672   5.676746
# 18     Intl Charge -1.293351   2.851643
# 19  CustServ Calls -0.195893   6.273601
# 20          Churn? -0.280065   9.953533
