# %% [markdown]
# # Data wrangling
# Transformacion de los datos para poder colocarlos en un estado correcto para modelizar

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
coursePath='C:/Users/jcres/Anaconda Projects/Course/python-ml-course-master/'
datasetsPath=coursePath+'datasets/'
workingPath='C:/Users/jcres/Anaconda Projects/Course/1 Data Cleaning/Files/'

# %%
titanicFilename='titanic/titanic3.csv'
customerChurnModelFilename='customer-churn-model/Customer Churn Model.txt'
titanicDataSet=os.path.join(datasetsPath,titanicFilename)
customerChurnModelDataSet=os.path.join(datasetsPath,customerChurnModelFilename)

# %%
data = pd.read_csv(customerChurnModelDataSet)

# %%
data.head(10)
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
# 5    AL             118        510  391-8027        yes         no
# 6    MA             121        510  355-9993         no        yes
# 7    MO             147        415  329-9001        yes         no
# 8    LA             117        408  335-4719         no         no
# 9    WV             141        415  330-8173        yes        yes
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# ...

# %% [markdown]
# ## Crear un subconjunto de datos

# %%
account_length=data["Account Length"]

# %%
account_length.head()
# Out:
# 0    128
# 1    107
# 2    137
# 3     84
# 4     75
# Name: Account Length, dtype: int64

# %%
type(account_length)
# Out:
# pandas.core.series.Series

# %%
subset = data[["Account Length","Phone","Eve Charge","Day Calls"]]

# %%
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
type(subset)
# Out:
# pandas.core.frame.DataFrame

# %%
desired_columns=["Account Length","Phone","Eve Charge","Day Calls"]
subset = data[desired_columns]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
all_columns_list = data.columns.values.tolist()
all_columns_list
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
sublist = (x for x in all_columns_list if x not in desired_columns)
subset=data[list(sublist)]

# %%
## Entregando una lista a la inversa

# %%
subset.head()
# Out:
#   State  Area Code Int'l Plan VMail Plan  VMail Message  Day Mins  Day Charge  \
# 0    KS        415         no        yes             25     265.1       45.07
# 1    OH        415         no        yes             26     161.6       27.47
# 2    NJ        415         no         no              0     243.4       41.38
# 3    OH        408        yes         no              0     299.4       50.90
# 4    OK        415        yes         no              0     166.7       28.34
#
#    Eve Mins  Eve Calls  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 0     197.4         99       244.7           91         11.01       10.0
# 1     195.5        103       254.4          103         11.45       13.7
# 2     121.2        110       162.6          104          7.32       12.2
# 3      61.9         88       196.9           89          8.86        6.6
# 4     148.3        122       186.9          121          8.41       10.1
#
#    Intl Calls  Intl Charge  CustServ Calls  Churn?
# ...

# %% [markdown]
# ## sub conjunto de filas con condiciones

# %%
data[10:25]
# Out:
#    State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 10    IN              65        415  329-6603         no         no
# 11    RI              74        415  344-9403         no         no
# 12    IA             168        408  363-1107         no         no
# 13    MT              95        510  394-8006         no         no
# 14    IA              62        415  366-9238         no         no
# 15    NY             161        415  351-7269         no         no
# 16    ID              85        408  350-8884         no        yes
# 17    VT              93        510  386-2923         no         no
# 18    VA              76        510  356-2992         no        yes
# 19    TX              73        415  373-2782         no         no
# 20    FL             147        415  396-5800         no         no
# 21    CO              77        408  393-7984         no         no
# 22    AZ             130        415  358-1958         no         no
# ...

# %%
data[:7]
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
# 5    AL             118        510  391-8027        yes         no
# 6    MA             121        510  355-9993         no        yes
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
# ...

# %%
data1=data[data["Eve Calls"]==99]
data1.head()
# Out:
#     State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0      KS             128        415  382-4657         no        yes
# 22     AZ             130        415  358-1958         no         no
# 38     AK             136        415  402-1381        yes        yes
# 290    CT             199        415  393-6733         no        yes
# 374    AZ              90        415  422-4241         no         no
#
#      VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0               25     265.1        110       45.07   ...           99
# 22               0     183.0        112       31.11   ...           99
# 38              33     203.9        106       34.66   ...           99
# 290             34     230.6        121       39.20   ...           99
# 374              0     179.2         77       30.46   ...           99
#
#      Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
data2=data[data["State"]=="NY"]
data2.head()
# Out:
#     State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15     NY             161        415  351-7269         no         no
# 77     NY             144        408  360-1171         no         no
# 136    NY              75        415  374-8525         no        yes
# 182    NY              67        408  405-2888         no        yes
# 186    NY             106        408  422-1471         no         no
#
#      VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 15               0     332.9         67       56.59   ...           97
# 77               0      61.6        117       10.47   ...           85
# 136             21     175.8         97       29.89   ...          106
# 182             36     115.6        111       19.65   ...           94
# 186              0     158.7         74       26.98   ...          139
#
#      Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
data4=data[(data["Day Mins"]>200) & (data["State"]=="NY")]
data4.shape
# Out:
# (23, 21)

# %% [markdown]
# ### and es & or es |

# %% [markdown]
# ## Numeros aleatorios

# %%
import numpy as np

# %%
np.random.rand()
# Out:
# 0.6229416674447933

# %%
def randint_list(n,a,b):
    x=[]
    for i in range(n):
        x.append(np.random.randint(a,b))
    return x

randint_list(10,1,40)
# Out:
# [8, 35, 38, 1, 5, 34, 12, 30, 34, 12]

# %%
import random

# %%
for i in range(10):
    print(random.randrange(0,100,7))
# Out:
# 42
# 7
# 70
# 98
# 0
# 63
# 7
# 56
# 35
# 7

# %%
##Semiila
np.random.seed(2018)
for i in range(6):
    print(np.random.random())
# Out:
# 0.8823493117539459
# 0.10432773786047767
# 0.9070093335163405
# 0.3063988986063515
# 0.446408872427422
# 0.5899853915235483
